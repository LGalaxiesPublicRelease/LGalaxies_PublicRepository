# %%
#========================================================================
#
#   Sample code to read in the L-galaxies hdf5 data 
#
#
#=======================================================================
 
import h5py 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import time
# %matplotlib inline

# %%
snap='20'
filenr=5

with h5py.File('../../output/SA_output_%i.h5' %filenr,'r') as f:
    
    #Get the data from the snapshot
    data=f[snap]
    #Get an array of the data returned
    Mvir=data['Mvir']

    # want to only plot galaxies which have a central viral mass than 20
    selection=[Mvir>20.0]
    
    # Get the coordinates of the data
    x=f[snap]['Pos'][:,0][selection]
    y=f[snap]['Pos'][:,1][selection]  
    z=f[snap]['Pos'][:,2][selection]  

    #Output the possible data labels where the first 3 are: table class, table version, table name
    print(list(f[snap].attrs.values()))
# Out:
# [b'TABLE', b'3.0', b'20', b'Type', b'HaloIndex', b'SnapNum', b'LookBackTimeToSnap', b'CentralMvir', b'CentralRvir', b'DistanceToCentralGal', b'Pos', b'Vel', b'Len', b'Mvir', b'Rvir', b'Vvir', b'Vmax', b'GasSpin', b'StellarSpin', b'InfallVmax', b'InfallVmaxPeak', b'InfallSnap', b'InfallHotGas', b'HotRadius', b'OriMergTime', b'MergTime', b'ColdGas', b'StellarMass', b'BulgeMass', b'DiskMass', b'HotGas', b'EjectedMass', b'BlackHoleMass', b'ICM', b'MetalsColdGas', b'MetalsStellarMass', b'MetalsBulgeMass', b'MetalsDiskMass', b'MetalsHotGas', b'MetalsEjectedMass', b'MetalsICM', b'PrimordialAccretionRate', b'CoolingRadius', b'CoolingRate', b'CoolingRate_beforeAGN', b'QuasarAccretionRate', b'RadioAccretionRate', b'Sfr', b'SfrBulge', b'XrayLum', b'BulgeSize', b'StellarDiskRadius', b'GasDiskRadius', b'CosInclination', b'DisruptOn', b'MergeOn', b'MagDust', b'Mag', b'MagBulge', b'MassWeightAge', b'rbandWeightAge', b'sfh_ibin', b'sfh_numbins', b'sfh_DiskMass', b'sfh_BulgeMass', b'sfh_ICM', b'sfh_MetalsDiskMass', b'sfh_MetalsBulgeMass', b'sfh_MetalsICM']

# %%
#make a simple plot of the data
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z,marker='o',s=4)
fig.savefig("L_gal_scatter_plot.png")
